# %%
import os
import datetime
import random
from datetime import datetime,timedelta

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
import datetime
raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(1, 101):
    timestamp = (start_time + datetime.timedelta(seconds=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]

    value = round(random.uniform(min_val, max_val), 2)

    reading = (
        timestamp,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:100]:
    print(reading)


# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []

for reading in raw_sensor_data:

    timestamp = reading[0]
    device_id = reading[1]
    device_type = reading[2]
    location = reading[3]
    value = reading[4]

    if device_type == "Temperature_Sensor":

        temp = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp)

print(temperature_readings)





# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()
for reading in raw_sensor_data:
    unique_locations.add(reading[3])
print(unique_locations)


# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    minimum, maximum = device_stats[device_type]
    if value < minimum:
        minimum = value
    if value > maximum:
        maximum = value
    device_stats[device_type] = (minimum,maximum)
print(device_stats)



# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_1)
print(sliced_readings_2)


# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
sample_string = "PythonProgrammingIsFun"
sub_string_1 = sample_string[6:17]
sub_string_2 = sample_string[5::-1]
print(sub_string_1)
print(sub_string_2)


# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6::]
print(fifth_reading_device_type)
print(device_type_suffix)



# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(readings_list, target_location):
    location_readings = []
    for reading in readings_list:
        if reading[3] == target_location:
            location_readings.append(reading)
    return location_readings

# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0
    total = 0
    for reading in temp_data_list:
        average = total / len(temp_data_list)
    return average


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
def generate_report_line(reading_dict):
    report = (f"[{reading_dict['timestamp']}]"
    f"Device {reading_dict['device_id']}"
    f"at {reading_dict['location']}: "
    f"{reading_dict['temperature_celsius']}C"
    )
    return report


# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")



# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")



# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:

read_report_lines = []
try:
    with open(report_filename, "r") as file:
        read_report_lines = file.readlines()
    print("First 3 lines of the report: ")
    for line in read_report_lines[:3]:
        print(line.strip())
except IOError as e:
    print("Error reading file:", e)
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")




print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-20 15:48:13', 'DEV001', 'Temperature_Sensor', 'Lab1', 28.78)
# ('2026-07-20 15:48:14', 'DEV002', 'Light_Sensor', 'OfficeA', 268.82)
# ('2026-07-20 15:48:15', 'DEV003', 'Humidity_Sensor', 'Lab2', 70.95)
# ('2026-07-20 15:48:16', 'DEV004', 'Light_Sensor', 'OfficeB', 981.23)
# ('2026-07-20 15:48:17', 'DEV005', 'Humidity_Sensor', 'Lab1', 71.14)
# ('2026-07-20 15:48:18', 'DEV006', 'Humidity_Sensor', 'OfficeA', 39.91)
# ('2026-07-20 15:48:19', 'DEV007', 'Humidity_Sensor', 'Lab2', 77.46)
# ('2026-07-20 15:48:20', 'DEV008', 'Temperature_Sensor', 'OfficeA', 21.58)
# ('2026-07-20 15:48:21', 'DEV009', 'Pressure_Sensor', 'OfficeA', 1003.16)
# ('2026-07-20 15:48:22', 'DEV010', 'Light_Sensor', 'Lab2', 142.52)
# ('2026-07-20 15:48:23', 'DEV011', 'Light_Sensor', 'Warehouse', 924.59)
# ('2026-07-20 15:48:24', 'DEV012', 'Pressure_Sensor', 'Lab2', 980.38)
# ('2026-07-20 15:48:25', 'DEV013', 'Pressure_Sensor', 'OfficeB', 988.0)
# ('2026-07-20 15:48:26', 'DEV014', 'Temperature_Sensor', 'Lab1', 23.49)
# ('2026-07-20 15:48:27', 'DEV015', 'Pressure_Sensor', 'OfficeA', 1016.01)
# ('2026-07-20 15:48:28', 'DEV016', 'Temperature_Sensor', 'OfficeA', 22.31)
# ('2026-07-20 15:48:29', 'DEV017', 'Temperature_Sensor', 'OfficeA', 24.02)
# ('2026-07-20 15:48:30', 'DEV018', 'Temperature_Sensor', 'OfficeA', 23.23)
# ('2026-07-20 15:48:31', 'DEV019', 'Light_Sensor', 'Lab1', 287.34)
# ('2026-07-20 15:48:32', 'DEV020', 'Humidity_Sensor', 'Lab2', 58.86)
# ('2026-07-20 15:48:33', 'DEV021', 'Humidity_Sensor', 'Warehouse', 39.5)
# ('2026-07-20 15:48:34', 'DEV022', 'Humidity_Sensor', 'Lab1', 65.03)
# ('2026-07-20 15:48:35', 'DEV023', 'Light_Sensor', 'OfficeA', 784.0)
# ('2026-07-20 15:48:36', 'DEV024', 'Light_Sensor', 'OfficeA', 237.28)
# ('2026-07-20 15:48:37', 'DEV025', 'Light_Sensor', 'Lab1', 376.29)
# ('2026-07-20 15:48:38', 'DEV026', 'Light_Sensor', 'Lab1', 751.58)
# ('2026-07-20 15:48:39', 'DEV027', 'Pressure_Sensor', 'Warehouse', 990.09)
# ('2026-07-20 15:48:40', 'DEV028', 'Pressure_Sensor', 'Lab1', 1007.67)
# ('2026-07-20 15:48:41', 'DEV029', 'Light_Sensor', 'Lab2', 210.59)
# ('2026-07-20 15:48:42', 'DEV030', 'Humidity_Sensor', 'Warehouse', 77.92)
# ('2026-07-20 15:48:43', 'DEV031', 'Temperature_Sensor', 'Lab1', 26.6)
# ('2026-07-20 15:48:44', 'DEV032', 'Temperature_Sensor', 'OfficeB', 27.1)
# ('2026-07-20 15:48:45', 'DEV033', 'Pressure_Sensor', 'Warehouse', 986.65)
# ('2026-07-20 15:48:46', 'DEV034', 'Temperature_Sensor', 'Lab2', 19.87)
# ('2026-07-20 15:48:47', 'DEV035', 'Temperature_Sensor', 'Warehouse', 20.99)
# ('2026-07-20 15:48:48', 'DEV036', 'Light_Sensor', 'Lab2', 536.15)
# ('2026-07-20 15:48:49', 'DEV037', 'Pressure_Sensor', 'Warehouse', 1020.39)
# ('2026-07-20 15:48:50', 'DEV038', 'Temperature_Sensor', 'OfficeB', 19.11)
# ('2026-07-20 15:48:51', 'DEV039', 'Humidity_Sensor', 'Lab2', 39.9)
# ('2026-07-20 15:48:52', 'DEV040', 'Light_Sensor', 'Lab1', 528.26)
# ('2026-07-20 15:48:53', 'DEV041', 'Temperature_Sensor', 'OfficeB', 28.58)
# ('2026-07-20 15:48:54', 'DEV042', 'Pressure_Sensor', 'Warehouse', 1029.51)
# ('2026-07-20 15:48:55', 'DEV043', 'Pressure_Sensor', 'Warehouse', 990.11)
# ('2026-07-20 15:48:56', 'DEV044', 'Humidity_Sensor', 'Lab2', 31.77)
# ('2026-07-20 15:48:57', 'DEV045', 'Pressure_Sensor', 'OfficeB', 1015.98)
# ('2026-07-20 15:48:58', 'DEV046', 'Light_Sensor', 'Warehouse', 927.76)
# ('2026-07-20 15:48:59', 'DEV047', 'Humidity_Sensor', 'OfficeB', 56.74)
# ('2026-07-20 15:49:00', 'DEV048', 'Humidity_Sensor', 'Warehouse', 65.82)
# ('2026-07-20 15:49:01', 'DEV049', 'Temperature_Sensor', 'Warehouse', 24.04)
# ('2026-07-20 15:49:02', 'DEV050', 'Pressure_Sensor', 'OfficeA', 994.74)
# ('2026-07-20 15:49:03', 'DEV051', 'Humidity_Sensor', 'OfficeB', 58.88)
# ('2026-07-20 15:49:04', 'DEV052', 'Pressure_Sensor', 'Lab1', 1029.94)
# ('2026-07-20 15:49:05', 'DEV053', 'Humidity_Sensor', 'Lab2', 41.63)
# ('2026-07-20 15:49:06', 'DEV054', 'Temperature_Sensor', 'Warehouse', 22.56)
# ('2026-07-20 15:49:07', 'DEV055', 'Humidity_Sensor', 'Lab1', 41.55)
# ('2026-07-20 15:49:08', 'DEV056', 'Light_Sensor', 'OfficeA', 153.13)
# ('2026-07-20 15:49:09', 'DEV057', 'Light_Sensor', 'Lab1', 141.47)
# ('2026-07-20 15:49:10', 'DEV058', 'Pressure_Sensor', 'Lab2', 1000.27)
# ('2026-07-20 15:49:11', 'DEV059', 'Pressure_Sensor', 'OfficeB', 1025.67)
# ('2026-07-20 15:49:12', 'DEV060', 'Pressure_Sensor', 'OfficeA', 998.67)
# ('2026-07-20 15:49:13', 'DEV061', 'Humidity_Sensor', 'Lab1', 45.95)
# ('2026-07-20 15:49:14', 'DEV062', 'Temperature_Sensor', 'Warehouse', 22.26)
# ('2026-07-20 15:49:15', 'DEV063', 'Humidity_Sensor', 'Lab2', 31.04)
# ('2026-07-20 15:49:16', 'DEV064', 'Pressure_Sensor', 'Warehouse', 1005.05)
# ('2026-07-20 15:49:17', 'DEV065', 'Light_Sensor', 'Lab2', 874.83)
# ('2026-07-20 15:49:18', 'DEV066', 'Temperature_Sensor', 'OfficeB', 18.0)
# ('2026-07-20 15:49:19', 'DEV067', 'Humidity_Sensor', 'OfficeB', 61.3)
# ('2026-07-20 15:49:20', 'DEV068', 'Temperature_Sensor', 'Lab1', 23.48)
# ('2026-07-20 15:49:21', 'DEV069', 'Light_Sensor', 'OfficeA', 397.3)
# ('2026-07-20 15:49:22', 'DEV070', 'Pressure_Sensor', 'Lab1', 1027.77)
# ('2026-07-20 15:49:23', 'DEV071', 'Temperature_Sensor', 'Lab1', 24.1)
# ('2026-07-20 15:49:24', 'DEV072', 'Temperature_Sensor', 'Lab1', 28.07)
# ('2026-07-20 15:49:25', 'DEV073', 'Pressure_Sensor', 'OfficeB', 999.4)
# ('2026-07-20 15:49:26', 'DEV074', 'Temperature_Sensor', 'Warehouse', 26.89)
# ('2026-07-20 15:49:27', 'DEV075', 'Temperature_Sensor', 'Warehouse', 19.97)
# ('2026-07-20 15:49:28', 'DEV076', 'Temperature_Sensor', 'Lab1', 27.85)
# ('2026-07-20 15:49:29', 'DEV077', 'Pressure_Sensor', 'Lab2', 1026.61)
# ('2026-07-20 15:49:30', 'DEV078', 'Pressure_Sensor', 'Lab1', 1007.71)
# ('2026-07-20 15:49:31', 'DEV079', 'Temperature_Sensor', 'Lab2', 26.34)
# ('2026-07-20 15:49:32', 'DEV080', 'Pressure_Sensor', 'OfficeB', 1027.87)
# ('2026-07-20 15:49:33', 'DEV081', 'Light_Sensor', 'Warehouse', 305.03)
# ('2026-07-20 15:49:34', 'DEV082', 'Temperature_Sensor', 'OfficeA', 29.9)
# ('2026-07-20 15:49:35', 'DEV083', 'Pressure_Sensor', 'OfficeB', 989.97)
# ('2026-07-20 15:49:36', 'DEV084', 'Temperature_Sensor', 'OfficeB', 29.76)
# ('2026-07-20 15:49:37', 'DEV085', 'Pressure_Sensor', 'Lab1', 983.08)
# ('2026-07-20 15:49:38', 'DEV086', 'Temperature_Sensor', 'Lab1', 29.06)
# ('2026-07-20 15:49:39', 'DEV087', 'Light_Sensor', 'OfficeB', 395.79)
# ('2026-07-20 15:49:40', 'DEV088', 'Pressure_Sensor', 'OfficeA', 998.75)
# ('2026-07-20 15:49:41', 'DEV089', 'Humidity_Sensor', 'OfficeB', 45.93)
# ('2026-07-20 15:49:42', 'DEV090', 'Pressure_Sensor', 'OfficeA', 1017.18)
# ('2026-07-20 15:49:43', 'DEV091', 'Pressure_Sensor', 'Lab2', 1018.29)
# ('2026-07-20 15:49:44', 'DEV092', 'Light_Sensor', 'Warehouse', 202.46)
# ('2026-07-20 15:49:45', 'DEV093', 'Light_Sensor', 'Warehouse', 416.82)
# ('2026-07-20 15:49:46', 'DEV094', 'Humidity_Sensor', 'Lab1', 55.16)
# ('2026-07-20 15:49:47', 'DEV095', 'Humidity_Sensor', 'OfficeB', 68.09)
# ('2026-07-20 15:49:48', 'DEV096', 'Pressure_Sensor', 'Lab2', 1013.4)
# ('2026-07-20 15:49:49', 'DEV097', 'Light_Sensor', 'OfficeB', 667.76)
# ('2026-07-20 15:49:50', 'DEV098', 'Temperature_Sensor', 'OfficeB', 21.64)
# ('2026-07-20 15:49:51', 'DEV099', 'Temperature_Sensor', 'OfficeA', 22.93)
# ('2026-07-20 15:49:52', 'DEV100', 'Light_Sensor', 'Warehouse', 439.14)
# [{'timestamp': '2026-07-20 15:48:13', 'device_id': 'DEV001', 'location': 'Lab1', 'temperature_celsius': 28.78}, {'timestamp': '2026-07-20 15:48:20', 'device_id': 'DEV008', 'location': 'OfficeA', 'temperature_celsius': 21.58}, {'timestamp': '2026-07-20 15:48:26', 'device_id': 'DEV014', 'location': 'Lab1', 'temperature_celsius': 23.49}, {'timestamp': '2026-07-20 15:48:28', 'device_id': 'DEV016', 'location': 'OfficeA', 'temperature_celsius': 22.31}, {'timestamp': '2026-07-20 15:48:29', 'device_id': 'DEV017', 'location': 'OfficeA', 'temperature_celsius': 24.02}, {'timestamp': '2026-07-20 15:48:30', 'device_id': 'DEV018', 'location': 'OfficeA', 'temperature_celsius': 23.23}, {'timestamp': '2026-07-20 15:48:43', 'device_id': 'DEV031', 'location': 'Lab1', 'temperature_celsius': 26.6}, {'timestamp': '2026-07-20 15:48:44', 'device_id': 'DEV032', 'location': 'OfficeB', 'temperature_celsius': 27.1}, {'timestamp': '2026-07-20 15:48:46', 'device_id': 'DEV034', 'location': 'Lab2', 'temperature_celsius': 19.87}, {'timestamp': '2026-07-20 15:48:47', 'device_id': 'DEV035', 'location': 'Warehouse', 'temperature_celsius': 20.99}, {'timestamp': '2026-07-20 15:48:50', 'device_id': 'DEV038', 'location': 'OfficeB', 'temperature_celsius': 19.11}, {'timestamp': '2026-07-20 15:48:53', 'device_id': 'DEV041', 'location': 'OfficeB', 'temperature_celsius': 28.58}, {'timestamp': '2026-07-20 15:49:01', 'device_id': 'DEV049', 'location': 'Warehouse', 'temperature_celsius': 24.04}, {'timestamp': '2026-07-20 15:49:06', 'device_id': 'DEV054', 'location': 'Warehouse', 'temperature_celsius': 22.56}, {'timestamp': '2026-07-20 15:49:14', 'device_id': 'DEV062', 'location': 'Warehouse', 'temperature_celsius': 22.26}, {'timestamp': '2026-07-20 15:49:18', 'device_id': 'DEV066', 'location': 'OfficeB', 'temperature_celsius': 18.0}, {'timestamp': '2026-07-20 15:49:20', 'device_id': 'DEV068', 'location': 'Lab1', 'temperature_celsius': 23.48}, {'timestamp': '2026-07-20 15:49:23', 'device_id': 'DEV071', 'location': 'Lab1', 'temperature_celsius': 24.1}, {'timestamp': '2026-07-20 15:49:24', 'device_id': 'DEV072', 'location': 'Lab1', 'temperature_celsius': 28.07}, {'timestamp': '2026-07-20 15:49:26', 'device_id': 'DEV074', 'location': 'Warehouse', 'temperature_celsius': 26.89}, {'timestamp': '2026-07-20 15:49:27', 'device_id': 'DEV075', 'location': 'Warehouse', 'temperature_celsius': 19.97}, {'timestamp': '2026-07-20 15:49:28', 'device_id': 'DEV076', 'location': 'Lab1', 'temperature_celsius': 27.85}, {'timestamp': '2026-07-20 15:49:31', 'device_id': 'DEV079', 'location': 'Lab2', 'temperature_celsius': 26.34}, {'timestamp': '2026-07-20 15:49:34', 'device_id': 'DEV082', 'location': 'OfficeA', 'temperature_celsius': 29.9}, {'timestamp': '2026-07-20 15:49:36', 'device_id': 'DEV084', 'location': 'OfficeB', 'temperature_celsius': 29.76}, {'timestamp': '2026-07-20 15:49:38', 'device_id': 'DEV086', 'location': 'Lab1', 'temperature_celsius': 29.06}, {'timestamp': '2026-07-20 15:49:50', 'device_id': 'DEV098', 'location': 'OfficeB', 'temperature_celsius': 21.64}, {'timestamp': '2026-07-20 15:49:51', 'device_id': 'DEV099', 'location': 'OfficeA', 'temperature_celsius': 22.93}]
# {'OfficeA', 'OfficeB', 'Warehouse', 'Lab2', 'Lab1'}
# {'Temperature_Sensor': (18.0, 29.9), 'Humidity_Sensor': (31.04, 77.92), 'Pressure_Sensor': (980.38, 1029.94), 'Light_Sensor': (141.47, 981.23)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-07-20 15:48:22', 'DEV010', 'Light_Sensor', 'Lab2', 142.52), ('2026-07-20 15:48:23', 'DEV011', 'Light_Sensor', 'Warehouse', 924.59), ('2026-07-20 15:48:24', 'DEV012', 'Pressure_Sensor', 'Lab2', 980.38), ('2026-07-20 15:48:25', 'DEV013', 'Pressure_Sensor', 'OfficeB', 988.0), ('2026-07-20 15:48:26', 'DEV014', 'Temperature_Sensor', 'Lab1', 23.49), ('2026-07-20 15:48:27', 'DEV015', 'Pressure_Sensor', 'OfficeA', 1016.01), ('2026-07-20 15:48:28', 'DEV016', 'Temperature_Sensor', 'OfficeA', 22.31), ('2026-07-20 15:48:29', 'DEV017', 'Temperature_Sensor', 'OfficeA', 24.02), ('2026-07-20 15:48:30', 'DEV018', 'Temperature_Sensor', 'OfficeA', 23.23), ('2026-07-20 15:48:31', 'DEV019', 'Light_Sensor', 'Lab1', 287.34), ('2026-07-20 15:48:32', 'DEV020', 'Humidity_Sensor', 'Lab2', 58.86)]
# [('2026-07-20 15:48:13', 'DEV001', 'Temperature_Sensor', 'Lab1', 28.78), ('2026-07-20 15:48:18', 'DEV006', 'Humidity_Sensor', 'OfficeA', 39.91), ('2026-07-20 15:48:23', 'DEV011', 'Light_Sensor', 'Warehouse', 924.59), ('2026-07-20 15:48:28', 'DEV016', 'Temperature_Sensor', 'OfficeA', 22.31), ('2026-07-20 15:48:33', 'DEV021', 'Humidity_Sensor', 'Warehouse', 39.5), ('2026-07-20 15:48:38', 'DEV026', 'Light_Sensor', 'Lab1', 751.58), ('2026-07-20 15:48:43', 'DEV031', 'Temperature_Sensor', 'Lab1', 26.6), ('2026-07-20 15:48:48', 'DEV036', 'Light_Sensor', 'Lab2', 536.15), ('2026-07-20 15:48:53', 'DEV041', 'Temperature_Sensor', 'OfficeB', 28.58), ('2026-07-20 15:48:58', 'DEV046', 'Light_Sensor', 'Warehouse', 927.76), ('2026-07-20 15:49:03', 'DEV051', 'Humidity_Sensor', 'OfficeB', 58.88), ('2026-07-20 15:49:08', 'DEV056', 'Light_Sensor', 'OfficeA', 153.13), ('2026-07-20 15:49:13', 'DEV061', 'Humidity_Sensor', 'Lab1', 45.95), ('2026-07-20 15:49:18', 'DEV066', 'Temperature_Sensor', 'OfficeB', 18.0), ('2026-07-20 15:49:23', 'DEV071', 'Temperature_Sensor', 'Lab1', 24.1), ('2026-07-20 15:49:28', 'DEV076', 'Temperature_Sensor', 'Lab1', 27.85), ('2026-07-20 15:49:33', 'DEV081', 'Light_Sensor', 'Warehouse', 305.03), ('2026-07-20 15:49:38', 'DEV086', 'Temperature_Sensor', 'Lab1', 29.06), ('2026-07-20 15:49:43', 'DEV091', 'Pressure_Sensor', 'Lab2', 1018.29), ('2026-07-20 15:49:48', 'DEV096', 'Pressure_Sensor', 'Lab2', 1013.4)]
# Programming
# nohtyP
# Humidity_Sensor
# Sensor
#
# --- Task 2: Function Definitions and Usage ---
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.
#
# Duration of data collection: 0 days, 0 hours, 1 minutes.
#
# Duration of data collection: 0 days, 0 hours, 1 minutes.
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
# First 3 lines of the report:
# [2026-07-20 15:48:13]Device DEV001at Lab1: 28.78C
# [2026-07-20 15:48:20]Device DEV008at OfficeA: 21.58C
# [2026-07-20 15:48:26]Device DEV014at Lab1: 23.49C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
